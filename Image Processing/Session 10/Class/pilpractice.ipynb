# %%
from PIL import Image

# %%
image = Image.open('The-One-Piece-Movies-In-Order-1-1140x641.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1140x640>

# %%
import cv2
import numpy as np

# %%
image_cv2 = np.array(image)

# %%
image_cv2
# Out:
# array([[[  8, 188, 247],
#         [  8, 188, 247],
#         [  8, 188, 247],
#         ...,
#         [  6, 150, 247],
#         [  6, 150, 247],
#         [  6, 150, 247]],
#
#        [[  8, 188, 247],
#         [  8, 188, 247],
#         [  8, 188, 247],
#         ...,
#         [  6, 150, 247],
#         [  6, 150, 247],
#         [  6, 150, 247]],
#
#        [[  8, 188, 247],
#         [  8, 188, 247],
#         [  8, 188, 247],
#         ...,
#         [  6, 150, 247],
#         [  6, 150, 247],
#         [  6, 150, 247]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [149, 229, 252],
#         [149, 229, 252],
#         [149, 229, 252]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [149, 229, 252],
#         [149, 229, 252],
#         [149, 229, 252]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [149, 229, 252],
#         [149, 229, 252],
#         [149, 229, 252]]], dtype=uint8)

# %%
image_pil = Image.fromarray(image_cv2)
image_pil
# Out:
# <PIL.Image.Image image mode=RGB size=1140x640>
