# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('online_retail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# df['InvoiveYearMonth'] = df['InvoiceDate'].dt.strftime('%Y-%m')
df['InvoiveYearMonth'] = df['InvoiceDate'].map(lambda date: 100*date.year + date.month)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  InvoiveYearMonth
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom            201012
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom            201012
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom            201012
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom            201012
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom            201012

# %%
df['Revenue'] = df['UnitPrice'] * df['Quantity']
df_revenue = df.groupby(df['InvoiveYearMonth'])['Revenue'].sum().reset_index()
df_revenue
# Out:
#     InvoiveYearMonth      Revenue
# 0             201012   748957.020
# 1             201101   560000.260
# 2             201102   498062.650
# 3             201103   683267.080
# 4             201104   493207.121
# 5             201105   723333.510
# 6             201106   691123.120
# 7             201107   681300.111
# 8             201108   682680.510
# 9             201109  1019687.622
# 10            201110  1070704.670
# 11            201111  1461756.250
# 12            201112   433668.010

# %%
plt.plot(df_revenue['InvoiveYearMonth'].astype(str), df_revenue['Revenue'], marker='o')

# %%
df_revenue['MonthlyGrowth'] = df_revenue['Revenue'].pct_change()
df_revenue.head()
# Out:
#    InvoiveYearMonth     Revenue  MonthlyGrowth
# 0            201012  748957.020            NaN
# 1            201101  560000.260      -0.252293
# 2            201102  498062.650      -0.110603
# 3            201103  683267.080       0.371850
# 4            201104  493207.121      -0.278163

# %%
plt.plot(df_revenue['InvoiveYearMonth'].astype(str), df_revenue['MonthlyGrowth'], marker='o')
