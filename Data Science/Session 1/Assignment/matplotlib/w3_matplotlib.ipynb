# %%
import matplotlib
import numpy as np

# %%
matplotlib.__version__
# Out:
# '3.7.2'

# %%
import matplotlib.pyplot as plt

xpoints = np.array([-3, 3])
ypoints = np.array([-5, 5])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, 3])
ypoints = np.array([-5, 5])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='|')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, 'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='o', ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='o', ms=10, mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='o', ms=10, mec='r', mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='o', ms=10, mec='r', mfc='#4CAF50')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, marker='o', ms=10, mec='r', mfc='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, ls='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, ls='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, lw='3')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average')
plt.ylabel('Median')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average')
plt.ylabel('Median')
plt.title('Median vs Average')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1, loc='left')
plt.ylabel('Median', fontdict=font1, loc='top')
plt.title('Median vs Average', fontdict=font2, loc='right')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.plot(ypoints, ls='dotted')
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.subplot(1, 2, 1)
plt.plot(ypoints, ls='dotted')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.grid(color='gray', ls='dashed', lw=0.5)

plt.subplot(1,2,2)
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.subplot(2, 1, 1)
plt.plot(ypoints, ls='dotted')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.title('Median vs Average', fontdict=font2)


plt.subplot(2,1,2)
plt.plot(xpoints, ls='dashed', color='r')
plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])
plt.scatter(xpoints, ypoints, color='g')

xpoints = np.array([-5, -2, 35, 3])
ypoints = np.array([-3, -16, 10, 22])
plt.scatter(xpoints, ypoints, color='orange')

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = np.array([ 45, 50, 55, 60])

xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])
plt.scatter(xpoints, ypoints, c=colors, cmap='viridis')

xpoints = np.array([-5, -2, 35, 3])
ypoints = np.array([-3, -16, 10, 22])
plt.scatter(xpoints, ypoints, c=colors, cmap='viridis')

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = np.array([ 45, 50, 55, 60])

xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])
plt.scatter(xpoints, ypoints, c=colors, cmap='PRGn')

xpoints = np.array([-5, -2, 35, 3])
ypoints = np.array([-3, -16, 10, 22])
plt.scatter(xpoints, ypoints, c=colors, cmap='PRGn')

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

colors = np.array([ 45, 50, 55, 60])
sizes = np.array([20,50,100,200])

xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])
plt.scatter(xpoints, ypoints, c=colors, cmap='prism', s=sizes)

xpoints = np.array([-5, -2, 35, 3])
ypoints = np.array([-3, -16, 10, 22])
plt.scatter(xpoints, ypoints, c=colors, cmap='prism', s=sizes)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

colors = np.array([ 45, 50, 55, 60])
sizes = np.array([20,50,100,200])

xpoints = np.array([-3, -16, 10, 22])
ypoints = np.array([-5, -2, 35, 3])
plt.scatter(xpoints, ypoints, c=colors, cmap='prism', s=sizes, alpha=0.5)

xpoints = np.array([-5, -2, 35, 3])
ypoints = np.array([-3, -16, 10, 22])
plt.scatter(xpoints, ypoints, c=colors, cmap='prism', s=sizes, alpha=0.9)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel('Average', fontdict=font1)
plt.ylabel('Median', fontdict=font1)
plt.title('Median vs Average', fontdict=font2)
plt.grid(color='gray', ls='dashed', lw=0.5)
plt.colorbar()
plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.grid(color='gray', ls='dashed', lw=0.5)

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.grid(color='gray', ls='dashed', lw=0.5)

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.grid(color='gray', ls='dashed', lw=0.5)

plt.barh(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.grid(color='gray', ls='dashed', lw=0.5)

plt.barh(x,y, color='orange')
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.grid(color='gray', ls='dashed', lw=0.5)

plt.bar(x,y, color='green')
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.grid(color='gray', ls='dashed', lw=0.5)

plt.bar(x,y, color='orange', width=0.1)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.grid(color='gray', ls='dashed', lw=0.5)

plt.barh(x,y, color='orange', height=0.1)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x, color = 'lightblue', edgecolor = 'black', bins = 30)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
labels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels=labels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
labels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels=labels, startangle=30)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
labels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.3, 0.2, 0.5, 0]

plt.pie(y, labels=labels, startangle=30, explode=myexplode, shadow=True, radius=1.2, autopct='%1.1f%%')
plt.show()

# %%
y = np.array([35, 25, 25, 15])
labels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.3, 0.2, 0.5, 0]

plt.pie(y, labels=labels, startangle=30, explode=myexplode, shadow=True, radius=1.2, autopct='%1.1f%%')
plt.legend()

plt.show()

# %%
y = np.array([35, 25, 25, 15])
labels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.3, 0.2, 0.5, 0]

plt.pie(y, labels=labels, startangle=30, explode=myexplode, shadow=True, radius=1.2, autopct='%1.1f%%')
plt.legend(title = "Four Fruits:", loc = "upper left")

plt.show()
