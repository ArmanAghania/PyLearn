# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = [110, 170, 65, 70, 20, 200, 150, 80]
Y = [40, 400, 30, 35, 25, 500, 55, 37]

# %%
plt.scatter(X, Y)
plt.show()

# %%
import matplotlib.pyplot as plt
X = np.random.random(100)
Y = np.random.random(100)

plt.scatter(X, Y)
plt.show()

# %%
X = np.random.random(100)
Y = X * 2

plt.scatter(X, Y)
plt.show()

# %%
import matplotlib.pyplot as plt
X = np.random.random(100) *200 + 15
Y = X * 2 + np.random.random(100) * 2 * 200
plt.scatter(X, Y)
plt.show()
